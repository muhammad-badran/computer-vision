# %% [markdown]
# # Installing OpenCV

# %%
# !pip install opencv-python

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- -------------------
# absl-py                            1.4.0
# accelerate                         1.1.1
# aiohappyeyeballs                   2.4.4
# aiohttp                            3.11.9
# aiosignal                          1.3.1
# alabaster                          1.0.0
# albucore                           0.0.19
# albumentations                     1.4.20
# altair                             4.2.2
# annotated-types                    0.7.0
# anyio                              3.7.1
# argon2-cffi                        23.1.0
# argon2-cffi-bindings               21.2.0
# array_record                       0.5.1
# arviz                              0.20.0
# astropy                            6.1.7
# astropy-iers-data                  0.2024.12.2.0.35.34
# astunparse                         1.6.3
# async-timeout                      4.0.3
# atpublic                           4.1.0
# ...

# %%
import cv2
import os

# %% [markdown]
# # Test Samples

# %% [markdown]
# Download opencv. Look for samples/python. Try hist and opt flow scripts.

# %% [markdown]
# # Reading Images

# %%
img_path1 = os.path.join('data', 'images', '1.jpg')
img_path2 = os.path.join('data', 'images', '2.jpg')

# %%
img_path2
# Out:
# 'data/images/2.jpg'

# %%
img1 = cv2.imread(img_path1)
img2 = cv2.imread(img_path2)

# %%
img2
# Out:
# array([[[226, 222, 204],
#         [223, 219, 201],
#         [218, 214, 196],
#         ...,
#         [241, 232, 219],
#         [241, 232, 219],
#         [241, 232, 219]],
#
#        [[208, 204, 186],
#         [210, 206, 188],
#         [214, 210, 192],
#         ...,
#         [241, 232, 219],
#         [241, 232, 219],
#         [241, 232, 219]],
#
#        [[228, 224, 206],
#         [228, 224, 206],
#         [230, 226, 208],
#         ...,
#         [241, 233, 220],
#         [241, 233, 220],
#         [241, 233, 220]],
#
#        ...,
#
#        [[ 95, 102, 121],
#         [ 95, 102, 121],
#         [ 95, 102, 121],
#         ...,
#         [ 86,  90, 101],
#         [ 86,  90, 101],
#         [ 86,  90, 101]],
#
#        [[102, 109, 128],
#         [102, 110, 127],
#         [102, 109, 128],
#         ...,
#         [ 82,  86,  97],
#         [ 82,  86,  97],
#         [ 82,  86,  97]],
#
#        [[ 55,  62,  79],
#         [ 55,  62,  77],
#         [ 58,  65,  82],
# ...

# %%
img2.shape
# Out:
# (169, 299, 3)

# %%
# to render image (colab show it, or cv2.imshow or matplotlib)
import matplotlib.pyplot as plt
plt.imshow(img1)

# %%
recolor1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
plt.imshow(recolor)

# %%
gray = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
plt.imshow(gray)

# %% [markdown]
# # Write out Image

# %%
cv2.imwrite('grayimage.jpg', gray)
# Out:
# True
